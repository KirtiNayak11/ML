# %% [markdown]
# <a href="https://colab.research.google.com/github/KirtiNayak11/ML/blob/main/AreaVsPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='green',marker='+')

# %%
area=df.iloc[:,:1].values
area
# Out:
# array([[2600],
#        [3000],
#        [3200],
#        [3600],
#        [4000]])

# %%
price=df.iloc[:,1:2].values
price
# Out:
# array([[550000],
#        [565000],
#        [610000],
#        [680000],
#        [725000]])

# %%
from sklearn.model_selection import train_test_split
trainin,testin,trainout,testout=train_test_split(area,price,test_size=1/3,random_state=0)

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(trainin,trainout)
# Out:
# LinearRegression()

# %%
testpred_price=model.predict(testin)

# %%
trainpred_price=model.predict(trainin)

# %%
plt.scatter(trainin,trainout,color='green')
plt.plot(trainin,trainpred_price,color='red')
plt.title("area vs price (Training dataset)")
plt.xlabel("area")
plt.ylabel("price")
plt.show()

# %%
plt.scatter(testin,testout,color='green')
plt.plot(trainin,trainpred_price,color='red')
plt.title("area vs price (Test Dataset) ")
plt.xlabel("area")
plt.ylabel("price")
plt.show()
